# %% [markdown]
# Importing necessary libraries

# %%
import numpy as np

# %% [markdown]
# Creating arrays

# %%
lst_1=[1,2,3,4]

# %%
arr_1=np.array(lst_1)

# %%
arr_1
# Out:
# array([1, 2, 3, 4])

# %%
lst2=[[1,2],[3,4]]

# %%
arr2=np.array(lst2)

# %%
arr2
# Out:
# array([[1, 2],
#        [3, 4]])

# %% [markdown]
# Modifing the array data

# %%
arr_1[2]=7

# %%
arr_1
# Out:
# array([1, 2, 7, 4])

# %%
arr2[1][0]=7

# %%
arr2
# Out:
# array([[1, 2],
#        [7, 4]])

# %% [markdown]
# Arithmetic operators

# %%
arr_1
# Out:
# array([1, 2, 7, 4])

# %%
arr2
# Out:
# array([[1, 2],
#        [7, 4]])

# %%
arr_1+arr2
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_2141/775386366.py in <cell line: 0>()
# ----> 1 arr_1+arr2
#
# ValueError: operands could not be broadcast together with shapes (4,) (2,2)

# %%
lst3=[5,6,7,8]

# %%
arr3=np.array(lst3)

# %%
arr3
# Out:
# array([5, 6, 7, 8])

# %%
arr_1+arr3
# Out:
# array([ 6,  8, 14, 12])

# %%
arr2+7
# Out:
# array([[ 8,  9],
#        [14, 11]])

# %%
arr_1+7
# Out:
# array([ 8,  9, 14, 11])

# %%
arr_1-7
# Out:
# array([-6, -5,  0, -3])

# %% [markdown]
# activity 1
# create an array

# %%
lst4=[5,10,15,20]

# %%
arr4=np.array (lst4)

# %%
arr4
# Out:
# array([ 5, 10, 15, 20])

# %% [markdown]
# Activity 2

# %%
lst5=[10,20,30,40]

# %%
arr=np.array(lst5)

# %%
arr
# Out:
# array([10, 20, 30, 40])

# %%
arr[3]
# Out:
# np.int64(40)

# %% [markdown]
# Activity 3
# change an element

# %%
arr[0]=100

# %%
arr
# Out:
# array([100,  20,  30,  40])

# %% [markdown]
# Activity 4
# add the two arrays andprint the result

# %%
lst=[1,2,3]

# %%
lst1=[4,5,6]

# %%
arr0=np.array(lst)

# %%
arr67=np.array (lst1)

# %%
arr0+arr67
# Out:
# array([5, 7, 9])

# %% [markdown]
# activity 5
# multiply to arrays

# %%
lst8=[2,3,4]

# %%
arr6=np.array(lst8)

# %%
lst9=[5,6,7]

# %%
arr7=np.array(lst9)

# %%
arr7*arr6
# Out:
# array([10, 18, 28])

# %% [markdown]
# Activity 6
# Square the nbumbers

# %%
lst8=[1,2,3,4]

# %%
arr9=np.array(lst8)

# %%
arr9*arr9
# Out:
# array([ 1,  4,  9, 16])

# %% [markdown]
# Activity 7
# add 10 to every number

# %%
lst_9=[5,10,15]

# %%
arr_=np.array(lst_9)

# %%
arr_+10
# Out:
# array([15, 20, 25])

# %% [markdown]
# Activity 8
# multiply every element by3

# %%
lst_=[2,4,6]

# %%
arr__=np.array (lst_)

# %%
arr__*3
# Out:
# array([ 6, 12, 18])

# %% [markdown]
# Activity 9
# ptint the following 2D array

# %%
lst6 =[[1,2,3],[4,5,6]]

# %%
arr8=np.array(lst6)

# %%
arr8
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %% [markdown]
# Activity 9
# print the element in the row 2 and colum 3

# %%
lst_2=[[10,20,30],[40,50,60]]

# %%
arr_2=np.array(lst_2)

# %%
arr_2[1][2]
# Out:
# np.int64(60)

# %%
arr_1
# Out:
# array([1, 2, 7, 4])

# %%
np.sum(arr_1)
# Out:
# np.int64(14)

# %%
np.mean(arr_1)
# Out:
# np.float64(3.5)

# %%
np.max(arr_1)
# Out:
# np.int64(7)

# %%
np.min (arr_1)
# Out:
# np.int64(1)

# %% [markdown]
# Matric multiplication

# %%
m1=np.array([[1,2],[3,4]])

# %%
m1
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
m2=np.array([[5,6],[7,8]])

# %%
m2
# Out:
# array([[5, 6],
#        [7, 8]])

# %%
np.dot(m1,m2)
# Out:
# array([[19, 22],
#        [43, 50]])
