# %% [markdown]
# # **Installing pandas**

# %%
# !pip install pandas

# %% [markdown]
# # **Importing pandas**

# %%
import pandas as pd

# %% [markdown]
# ## **creating dictionary**

# %%
dic1={'name':['Alice','Bob','Carlie'],'age':[25,30,35],'city':['delhi','mumbai','chennai']}

# %%
dic1
# Out:
# {'name': ['Alice', 'Bob', 'Carlie'],
#  'age': [25, 30, 35],
#  'city': ['delhi', 'mumbai', 'chennai']}

# %% [markdown]
# # **creating dataframe from dictionary**

# %%
df=pd.DataFrame(dic1)

# %%
df
# Out:
#      name  age     city
# 0   Alice   25    delhi
# 1     Bob   30   mumbai
# 2  Carlie   35  chennai

# %% [markdown]
# # **saving the dataframe**

# %%
df.to_csv('student.csv')

# %%
df.to_csv('student_1.csv',index=False)

# %%
df
# Out:
#      name  age     city
# 0   Alice   25    delhi
# 1     Bob   30   mumbai
# 2  Carlie   35  chennai

# %% [markdown]
# # **opening the csv file**

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_7166/1396537375.py in <cell line: 0>()
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
df=pd.read_csv('/content/student_1.csv')

# %%
df
# Out:
#      name  age     city
# 0   Alice   25    delhi
# 1     Bob   30   mumbai
# 2  Carlie   35  chennai

# %% [markdown]
# # ***Acitivity 1 - create a dataframe and save and open as csv***

# %%
dict1={'r.no':[1,2,3,4],'name':['arun','bala','raja','ravi'],'std':[3,5,7,12],'mark':[100,95,91,87]}

# %%
import pandas as pd

# %%
df2=pd.DataFrame(dict1)

# %%
df2
# Out:
#    r.no  name  std  mark
# 0     1  arun    3   100
# 1     2  bala    5    95
# 2     3  raja    7    91
# 3     4  ravi   12    87

# %%
df2.to_csv('marks.csv')

# %%
df2.to_csv('marks_1.csv',index=False)

# %%
df2=pd.read_csv('/content/marks_1.csv')

# %%
df2
# Out:
#    r.no  name  std  mark
# 0     1  arun    3   100
# 1     2  bala    5    95
# 2     3  raja    7    91
# 3     4  ravi   12    87

# %% [markdown]
# **I. list all the feature names**
# - r.no
# - name
# - std
# - marks
#
# **II. Total number of records** = 4
#
# **III. total number of features** =4
#
# **IV total number of index and list them** =4
# - 0
# - 1
# - 2
# - 3
