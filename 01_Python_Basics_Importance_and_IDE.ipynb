# %% [markdown]
# # **why python**
# - python is easy to learn
# - python has bigger community support

# %% [markdown]
# # **getting started with python**
# https://www.python.org/

# %%
# !python --version
# Out:
# Python 3.12.13

# %% [markdown]
# # **choose an IDE**
# - vs code
# - pycharm
# - python IDLE
# - jupyter notebook
# - colab

# %% [markdown]
# # **Run a code in colab**

# %%
print("Jeevika")
# Out:
# Jeevika

# %%
a=10
b=20

# %%
a+b
# Out:
# 30

# %%
a-b
# Out:
# -10

# %%
a
# Out:
# 10

# %%
b
# Out:
# 20

# %% [markdown]
# # **popular python packages**

# %%
import math
import os
import random
import requests
import pandas

# %% [markdown]
# ## **Funny story game**

# %%
c=5

# %%
c
# Out:
# 5

# %%
d=input("enter a number")
# Out:
# enter a number4

# %%
d
# Out:
# '4'

# %%
name=input("enter a name ")
place=input("enter a place ")
animal=input("enter a animal ")

print("your funny story")
print(name,"went to",place,"and saw a",animal,"dancing")
# Out:
# enter a name harini
# enter a place india
# enter a animal dog
# your funny story
# harini went to india and saw a dog dancing
