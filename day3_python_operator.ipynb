# %% [markdown]
# # **python operators**

# %% [markdown]
# 1.arithimetic operators

# %%
x=5
y=2

# %%
print(x+y)
# Out:
# 7

# %%
print(x-y)
# Out:
# 3

# %%
print(x*y)
# Out:
# 10

# %%
print(x/y)
# Out:
# 2.5

# %%
print(x**y)
# Out:
# 25

# %%
print(x%y)
# Out:
# 1

# %%
print(x//y)
# Out:
# 2

# %%
2-3-5
# Out:
# -6

# %% [markdown]
# 2.comprasior operators

# %%
print(x>y)
# Out:
# True

# %%
print(x<y)
# Out:
# False

# %%
print(x>=y)
# Out:
# True

# %%
print(x>=5)
# Out:
# True

# %%
print(x<=y)
print(x<=5)
# Out:
# False
# True

# %%
print(y==2)
# Out:
# True

# %%
print(y!=3)
# Out:
# True

# %% [markdown]
# 3.logical operators

# %%
is_student=True
has_access=False

# %%
print(is_student and has_access)
# Out:
# False

# %%
print(is_student or has_access)
# Out:
# True

# %%
print(not is_student )
# Out:
# False

# %% [markdown]
# 4.assignment operator

# %%
s=10

# %%
r=s+10
print(r)
# Out:
# 20

# %%
#r=r+10

# %%
r+=10

# %%
print(r)
# Out:
# 30

# %% [markdown]
# 5.membership operator

# %%
colour=["red","blue",'green','orange']

# %%
print(colour)
# Out:
# ['red', 'blue', 'green', 'orange']

# %%
'red' in colour
# Out:
# True

# %%
'red' not in colour
# Out:
# False

# %% [markdown]
# 6.Identy operator

# %%
p=[1,2,3]
q=[1,2,3]

# %%
p==q
# Out:
# True

# %%
p is q
# Out:
# False

# %%
u=[1,2,3]
v=u

# %%
u==v
# Out:
# True

# %%
u is v
# Out:
# True

# %% [markdown]
# **type checking**

# %%
type(u)
# Out:
# list

# %%
type(r)
# Out:
# int

# %% [markdown]
# # **Activity 1**

# %%
print(6+2)#8
# Out:
# 8

# %%
print(9-3)#6
# Out:
# 6

# %%
print(4*5)#20
# Out:
# 20

# %%
print(8/2)#4
# Out:
# 2

# %%
print(10%3)#1
# Out:
# 1

# %%
print(7+2)#9
# Out:
# 9

# %%
print(15-5)#10
# Out:
# 10

# %%
print(3*6)#18
# Out:
# 18

# %%
print(20/4)#5
# Out:
# 5.0

# %%
print(11%2)#1
# Out:
# 1

# %%
print(12+4)#16
# Out:
# 16

# %%
print(18//9)#2
# Out:
# 2

# %%
print(5*5)#25
# Out:
# 25

# %%
print(16//8)#2
# Out:
# 2

# %%
print(14%5)#4
# Out:
# 4

# %%
print(9+1)#10
# Out:
# 10

# %%
print(13-3)#10
# Out:
# 10

# %%
print(2*7)#14
# Out:
# 14

# %%
print(25/5)#5
# Out:
# 5.0

# %%
print(17%6)#5
# Out:
# 5

# %% [markdown]
# # **activity 2**

# %% [markdown]
# **de bug the code**

# %%
print(10=10)
# Out:
#   File "/tmp/ipykernel_15551/722493235.py", line 1
#     print(10=10)
#           ^
# SyntaxError: expression cannot contain assignment, perhaps you meant "=="?

# %%
print(10==10)
# Out:
# True
