# %% [markdown]
# # **Datatyps**

# %% [markdown]
# A kind of data that variable hold in the program language is called datatype

# %% [markdown]
# # **Basic data typs**

# %%
x=10
type(x)
# Out:
# int

# %%
pi=3.14
type(pi)
# Out:
# float

# %%
name='python'
type(name)
# Out:
# str

# %%
is_open=True
type(is_open)
# Out:
# bool

# %% [markdown]
# # **activity**
# to find the datatype of the given input

# %%
d=False
print(type(d))
# Out:
# <class 'bool'>

# %% [markdown]
# # **collection types**

# %% [markdown]
# ## **List**

# %%
lst_1=[10,3.14,'python',True]

# %%
lst_1
# Out:
# [10, 3.14, 'python', True]

# %% [markdown]
# - mutable
# - order

# %%
lst_1[0]
# Out:
# 10

# %%
lst_1[2]
# Out:
# 'python'

# %%
lst_1[3]
# Out:
# True

# %%
lst_1
# Out:
# [10, 3.14, 'python', True]

# %%
lst_1[0]
# Out:
# 10

# %%
lst_1[0]=20

# %%
lst_1
# Out:
# [20, 3.14, 'python', True]

# %% [markdown]
# # **Activity**

# %%
lst_1[3]=False

# %%
lst_1
# Out:
# [20, 3.14, 'python', False]

# %% [markdown]
# # **tuple**

# %%
tuple_1=(10,3.14,'python',True)

# %% [markdown]
# - Imutable
# - orderd

# %%
tuple_1[0]
# Out:
# 10

# %%
tuple_1[1]
# Out:
# 3.14

# %%
tuple_1[3]=False
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_9855/2982245628.py in <cell line: 0>()
# ----> 1 tuple_1[3]=False
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# # **Set**
# - unorder
# - unique

# %%
set_={10,3.14,'python',True}

# %%
set_
# Out:
# {10, 3.14, True, 'python'}

# %%
lst_2=[10,10,3.14,'python',True]
lst_2
# Out:
# [10, 10, 3.14, 'python', True]

# %%
tuple_2=(10,10,3.14,'python',True)
tuple_2
# Out:
# (10, 10, 3.14, 'python', True)

# %%
set_2={10,10,3.14,'python',True}
set_2
# Out:
# {10, 3.14, True, 'python'}

# %% [markdown]
# # **Dictionary**

# %%
dict_1={'name':'raja','std':3,'subject':'math','mark':100}
dict_1
# Out:
# {'name': 'raja', 'std': 3, 'subject': 'math', 'mark': 100}

# %%
dict_1['mark']
# Out:
# 100

# %%
dict_1['name']
# Out:
# 'raja'

# %% [markdown]
# # **Activity**

# %%
dict_1['mark']=200

# %%
dict_1
# Out:
# {'name': 'raja', 'std': 3, 'subject': 'math', 'mark': 200}

# %%
dict_1['subject']='science'

# %%
dict_1
# Out:
# {'name': 'raja', 'std': 3, 'subject': 'science', 'mark': 200}

# %%
w=input('enter a name')
v=input('enter your std')
dict_2={'name':w,'std':v}
# Out:
# enter a namenandita
# enter your std7

# %%
dict_2
# Out:
# {'name': 'nandita', 'std': '7'}

# %% [markdown]
# **pizza order**

# %%
r=input('enter your user name ')
c=input('enter the type of pizza ')
s=input('enter your credit card number ')
k=input('enter your topping you would like to have ')
b=input('type veg or non-veg ' )
p=input('type larg/mid/orsmall ' )
dict_={'user name':r ,'type of pizza':c ,'credit card number':s ,'topping':k ,
       'veg or non-veg':b ,'larg/mid/small':p}
print('pizzza time')
print('order details')
dict_
# Out:
# enter your user name uma
# enter the type of pizza margarita
# enter your credit card number 1234
# enter your topping you would like to have corn
# type veg or non-veg veg
# type larg/mid/orsmall mid
# pizzza time
# order details
# {'user name': 'uma',
#  'type of pizza': 'margarita',
#  'credit card number': '1234',
#  'topping': 'corn',
#  'veg or non-veg': 'veg',
#  'larg/mid/small': 'mid'}
